# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r"C:\Users\Akshata\Downloads\archive (6)\data_cardiovascular_risk.csv")
data
# Out:
#         id  age  education sex is_smoking  cigsPerDay  BPMeds  \
# 0        0   64        2.0   F        YES         3.0     0.0
# 1        1   36        4.0   M         NO         0.0     0.0
# 2        2   46        1.0   F        YES        10.0     0.0
# 3        3   50        1.0   M        YES        20.0     0.0
# 4        4   64        1.0   F        YES        30.0     0.0
# ...    ...  ...        ...  ..        ...         ...     ...
# 3385  3385   60        1.0   F         NO         0.0     0.0
# 3386  3386   46        1.0   F         NO         0.0     0.0
# 3387  3387   44        3.0   M        YES         3.0     0.0
# 3388  3388   60        1.0   M         NO         0.0     NaN
# 3389  3389   54        3.0   F         NO         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    221.0  148.0   85.0    NaN
# ...

# %%
data.head()
# Out:
#    id  age  education sex is_smoking  cigsPerDay  BPMeds  prevalentStroke  \
# 0   0   64        2.0   F        YES         3.0     0.0                0
# 1   1   36        4.0   M         NO         0.0     0.0                0
# 2   2   46        1.0   F        YES        10.0     0.0                0
# 3   3   50        1.0   M        YES        20.0     0.0                0
# 4   4   64        1.0   F        YES        30.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    221.0  148.0   85.0    NaN       90.0     80.0
# 1             1         0    212.0  168.0   98.0  29.77       72.0     75.0
# 2             0         0    250.0  116.0   71.0  20.35       88.0     94.0
# 3             1         0    233.0  158.0   88.0  28.26       68.0     94.0
# 4             0         0    241.0  136.5   85.0  26.42       70.0     77.0
#
#    TenYearCHD
# 0           1
# 1           0
# 2           0
# ...

# %%
data.drop(['id','education'],axis=1,inplace=True)
data
# Out:
#       age sex is_smoking  cigsPerDay  BPMeds  prevalentStroke  prevalentHyp  \
# 0      64   F        YES         3.0     0.0                0             0
# 1      36   M         NO         0.0     0.0                0             1
# 2      46   F        YES        10.0     0.0                0             0
# 3      50   M        YES        20.0     0.0                0             1
# 4      64   F        YES        30.0     0.0                0             0
# ...   ...  ..        ...         ...     ...              ...           ...
# 3385   60   F         NO         0.0     0.0                0             0
# 3386   46   F         NO         0.0     0.0                0             0
# 3387   44   M        YES         3.0     0.0                0             1
# 3388   60   M         NO         0.0     NaN                0             1
# 3389   54   F         NO         0.0     0.0                0             0
#
# ...

# %%
data.dtypes
# Out:
# age                  int64
# sex                 object
# is_smoking          object
# cigsPerDay         float64
# BPMeds             float64
# prevalentStroke      int64
# prevalentHyp         int64
# diabetes             int64
# totChol            float64
# sysBP              float64
# diaBP              float64
# BMI                float64
# heartRate          float64
# glucose            float64
# TenYearCHD           int64
# dtype: object

# %%
data.isna().sum()
# Out:
# age                  0
# sex                  0
# is_smoking           0
# cigsPerDay          22
# BPMeds              44
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             38
# sysBP                0
# diaBP                0
# BMI                 14
# heartRate            1
# glucose            304
# TenYearCHD           0
# dtype: int64

# %%
data
# Out:
#       age sex is_smoking  cigsPerDay  BPMeds  prevalentStroke  prevalentHyp  \
# 0      64   F        YES         3.0     0.0                0             0
# 1      36   M         NO         0.0     0.0                0             1
# 2      46   F        YES        10.0     0.0                0             0
# 3      50   M        YES        20.0     0.0                0             1
# 4      64   F        YES        30.0     0.0                0             0
# ...   ...  ..        ...         ...     ...              ...           ...
# 3385   60   F         NO         0.0     0.0                0             0
# 3386   46   F         NO         0.0     0.0                0             0
# 3387   44   M        YES         3.0     0.0                0             1
# 3388   60   M         NO         0.0     NaN                0             1
# 3389   54   F         NO         0.0     0.0                0             0
#
# ...

# %%
data.describe()
# Out:
#                age   cigsPerDay       BPMeds  prevalentStroke  prevalentHyp  \
# count  3390.000000  3368.000000  3346.000000      3390.000000   3390.000000
# mean     49.542183     9.069477     0.029886         0.006490      0.315339
# std       8.592878    11.879078     0.170299         0.080309      0.464719
# min      32.000000     0.000000     0.000000         0.000000      0.000000
# 25%      42.000000     0.000000     0.000000         0.000000      0.000000
# 50%      49.000000     0.000000     0.000000         0.000000      0.000000
# 75%      56.000000    20.000000     0.000000         0.000000      1.000000
# max      70.000000    70.000000     1.000000         1.000000      1.000000
#
#           diabetes      totChol       sysBP        diaBP          BMI  \
# count  3390.000000  3352.000000  3390.00000  3390.000000  3376.000000
# mean      0.025664   237.074284   132.60118    82.883038    25.794964
# std       0.158153    45.247430    22.29203    12.023581     4.115449
# ...

# %%
data.fillna(data.cigsPerDay.mean(),inplace=True)

# %%
data.fillna(data.BPMeds.mean(),inplace=True)

# %%
data.describe()
# Out:
#                age   cigsPerDay       BPMeds  prevalentStroke  prevalentHyp  \
# count  3390.000000  3390.000000  3390.000000      3390.000000   3390.000000
# mean     49.542183     9.069477     0.147214         0.006490      0.315339
# std       8.592878    11.840458     1.037191         0.080309      0.464719
# min      32.000000     0.000000     0.000000         0.000000      0.000000
# 25%      42.000000     0.000000     0.000000         0.000000      0.000000
# 50%      49.000000     0.000000     0.000000         0.000000      0.000000
# 75%      56.000000    20.000000     0.000000         0.000000      1.000000
# max      70.000000    70.000000     9.069477         1.000000      1.000000
#
#           diabetes      totChol       sysBP        diaBP          BMI  \
# count  3390.000000  3390.000000  3390.00000  3390.000000  3390.000000
# mean      0.025664   234.518478   132.60118    82.883038    25.725892
# std       0.158153    50.997526    22.29203    12.023581     4.244738
# ...

# %%
data.isna().sum()
# Out:
# age                0
# sex                0
# is_smoking         0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
data.dropna(how='all')
# Out:
#       age sex is_smoking  cigsPerDay    BPMeds  prevalentStroke  prevalentHyp  \
# 0      64   F        YES         3.0  0.000000                0             0
# 1      36   M         NO         0.0  0.000000                0             1
# 2      46   F        YES        10.0  0.000000                0             0
# 3      50   M        YES        20.0  0.000000                0             1
# 4      64   F        YES        30.0  0.000000                0             0
# ...   ...  ..        ...         ...       ...              ...           ...
# 3385   60   F         NO         0.0  0.000000                0             0
# 3386   46   F         NO         0.0  0.000000                0             0
# 3387   44   M        YES         3.0  0.000000                0             1
# 3388   60   M         NO         0.0  9.069477                0             1
# 3389   54   F         NO         0.0  0.000000                0             0
#
# ...

# %%
data.dtypes
# Out:
# age                  int64
# sex                 object
# is_smoking          object
# cigsPerDay         float64
# BPMeds             float64
# prevalentStroke      int64
# prevalentHyp         int64
# diabetes             int64
# totChol            float64
# sysBP              float64
# diaBP              float64
# BMI                float64
# heartRate          float64
# glucose            float64
# TenYearCHD           int64
# dtype: object

# %%
x=data.iloc[:,:15]
y=data.iloc[:,-1]

# %%
x
# Out:
#       age sex is_smoking  cigsPerDay    BPMeds  prevalentStroke  prevalentHyp  \
# 0      64   F        YES         3.0  0.000000                0             0
# 1      36   M         NO         0.0  0.000000                0             1
# 2      46   F        YES        10.0  0.000000                0             0
# 3      50   M        YES        20.0  0.000000                0             1
# 4      64   F        YES        30.0  0.000000                0             0
# ...   ...  ..        ...         ...       ...              ...           ...
# 3385   60   F         NO         0.0  0.000000                0             0
# 3386   46   F         NO         0.0  0.000000                0             0
# 3387   44   M        YES         3.0  0.000000                0             1
# 3388   60   M         NO         0.0  9.069477                0             1
# 3389   54   F         NO         0.0  0.000000                0             0
#
# ...

# %%
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 3385    0
# 3386    0
# 3387    1
# 3388    0
# 3389    0
# Name: TenYearCHD, Length: 3390, dtype: int64

# %%
data.select_dtypes('object').columns
# Out:
# Index(['sex', 'is_smoking'], dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for col in x.select_dtypes('object').columns:
    x[col]=le.fit_transform(x[col])

# %%
data.head()
# Out:
#    age sex is_smoking  cigsPerDay  BPMeds  prevalentStroke  prevalentHyp  \
# 0   64   F        YES         3.0     0.0                0             0
# 1   36   M         NO         0.0     0.0                0             1
# 2   46   F        YES        10.0     0.0                0             0
# 3   50   M        YES        20.0     0.0                0             1
# 4   64   F        YES        30.0     0.0                0             0
#
#    diabetes  totChol  sysBP  diaBP        BMI  heartRate  glucose  TenYearCHD
# 0         0    221.0  148.0   85.0   9.069477       90.0     80.0           1
# 1         0    212.0  168.0   98.0  29.770000       72.0     75.0           0
# 2         0    250.0  116.0   71.0  20.350000       88.0     94.0           0
# 3         0    233.0  158.0   88.0  28.260000       68.0     94.0           1
# 4         0    241.0  136.5   85.0  26.420000       70.0     77.0           0

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=12)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((2712, 15), (678, 15), (2712,), (678,))

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LeakyReLU,PReLU,ELU,ReLU

# %%
classifier=Sequential()

# %%
classifier.add(Dense(units=15,activation='relu'))

# %%
classifier.add(Dense(units=5,activation='relu'))

# %%
classifier.add(Dense(units=2,activation='relu'))

# %%
classifier.add(Dense(1,activation='sigmoid'))

# %%
import tensorflow
opt=tensorflow.keras.optimizers.Adam(learning_rate=0.01)

# %%
classifier.compile(optimizer=opt,loss='binary_crossentropy',metrics=['accuracy'])

# %%
import tensorflow as tf
early_stopping=tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0.0001,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False
)

# %%
model_history=classifier.fit(x_train,y_train,validation_split=0.33,batch_size=10,epochs=10)
# Out:
# Epoch 1/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9180 - loss: 0.1773 - val_accuracy: 0.9888 - val_loss: 0.0847
# Epoch 2/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9884 - loss: 0.0678 - val_accuracy: 0.9933 - val_loss: 0.0486
# Epoch 3/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9884 - loss: 0.0504 - val_accuracy: 0.9922 - val_loss: 0.0394
# Epoch 4/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9884 - loss: 0.0460 - val_accuracy: 0.9911 - val_loss: 0.0384
# Epoch 5/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9873 - loss: 0.0458 - val_accuracy: 0.9933 - val_loss: 0.0305
# Epoch 6/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9967 - loss: 0.0212 - val_accuracy: 1.0000 - val_loss: 0.0113
# Epoch 7/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9994 - loss: 0.0107 - val_accuracy: 1.0000 - val_loss: 0.0079
# Epoch 8/10
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
